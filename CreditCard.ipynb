# %% [markdown]
# <a href="https://colab.research.google.com/github/JoseEpitacio/CRUD_cadastraNota/blob/main/CreditCard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd

df_creditcard = pd.read_csv("creditcard.csv")
df_creditcard.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df_creditcard.dropna()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
X = df_creditcard.iloc[:,1:28].values
X
# Out:
# array([[-1.35980713e+00, -7.27811733e-02,  2.53634674e+00, ...,
#          1.28539358e-01, -1.89114844e-01,  1.33558377e-01],
#        [ 1.19185711e+00,  2.66150712e-01,  1.66480113e-01, ...,
#          1.67170404e-01,  1.25894532e-01, -8.98309914e-03],
#        [-1.35835406e+00, -1.34016307e+00,  1.77320934e+00, ...,
#         -3.27641834e-01, -1.39096572e-01, -5.53527940e-02],
#        ...,
#        [ 1.91956501e+00, -3.01253846e-01, -3.24963981e+00, ...,
#          2.65745453e-01, -8.73705959e-02,  4.45477214e-03],
#        [-2.40440050e-01,  5.30482513e-01,  7.02510230e-01, ...,
#         -5.69158864e-01,  5.46668462e-01,  1.08820735e-01],
#        [-5.33412522e-01, -1.89733337e-01,  7.03337367e-01, ...,
#         -4.73648704e-01, -8.18267121e-01, -2.41530880e-03]])

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters = 2, init = 'random')

# %%
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(init='random', n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.45900039e+00, -5.40438363e-01, -4.77693416e-01,
#          2.64303552e-01, -3.03525406e-01, -3.48466516e-02,
#         -2.87306352e-01,  2.90492577e-03,  1.99301888e-01,
#          1.51655087e-01,  8.68089721e-02,  9.06467441e-02,
#          1.36832219e-02,  2.30383447e-02,  7.35423454e-02,
#          3.68725756e-02, -1.19366528e-02, -5.83251816e-02,
#         -7.04508653e-02, -1.76957315e-02, -2.40405618e-02,
#         -7.30758118e-02, -5.27930678e-03,  8.68043584e-04,
#          1.22578270e-01,  1.03177859e-02, -1.62749971e-02],
#        [-1.30943285e+00,  4.85036022e-01,  4.28723293e-01,
#         -2.37208815e-01,  2.72409891e-01,  3.12743921e-02,
#          2.57853512e-01, -2.60713106e-03, -1.78870713e-01,
#         -1.36108362e-01, -7.79098625e-02, -8.13542102e-02,
#         -1.22805041e-02, -2.06765986e-02, -6.60032469e-02,
#         -3.30926312e-02,  1.07129823e-02,  5.23460510e-02,
#          6.32286859e-02,  1.58816765e-02,  2.15760746e-02,
# ...

# %%
distance = kmeans.fit_transform(X)
distance
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# array([[3.57207259, 4.88295162],
#        [3.62026415, 2.49646438],
#        [5.94703268, 6.66835358],
#        ...,
#        [6.67384174, 5.5779302 ],
#        [5.01481172, 5.44301889],
#        [2.7883416 , 3.91377445]])

# %%
labels = kmeans.labels_
labels
# Out:
# array([0, 1, 0, ..., 1, 0, 0], dtype=int32)

# %%
from sklearn.cluster import KMeans
wcss = []
i = 0
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'random')
    kmeans.fit(X)
    print (i,kmeans.inertia_)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('O Metodo Elbow')
plt.xlabel('Numero de Clusters')
plt.ylabel('WSS') #within cluster sum of squares
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 1 8721583.68479505
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 2 7951985.953290779
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 3 7526637.123939621
# ...
